# %%
import pandas as pd
df = pd.read_csv("pre_processed_data.csv")

# %%
df
# Out:
#                                                    0    1
# 0  evaluation tcm technegas ventilation scintigra...  C08
# 1  cardiorespiratory effects pressure controlled ...  C08
# 2  gastrointestinal disease oral contraception or...  C06
# 3  fat saturation mr imaging upper abdomen fat sa...  C06
# 4  isolation physicochemical characterization pre...  C01
# 5  new method evaluate capd catheter exit percuta...  C01
# 6  dentist dilemma nonsurgical endodontic therapy...  C07
# 7  osteomyelitis mandible result sickle cell dise...  C07
# 8  anterior inferior cerebellar artery internal a...  C09
# 9  scanning electron microscopic study nasopharyn...  C09

# %%
df = pd.read_csv("new.txt", sep=' ',header=None)

# %%
df
# Out:
#             0         1         2         3         4         5         6   \
# 0       0,</s>  0.008005  0.008839 -0.007661 -0.006556  0.002733  0.006042
# 1   1,patients -0.487951  1.691632  3.338713 -1.053598  1.189507  0.108303
# 2          2,p -7.501344  0.699352 -2.065420  0.938354  3.290108  0.857703
# 3    3,disease -0.428979  2.968171  2.739791  1.948644 -1.687813 -1.901850
# 4       4,less -6.981816  0.013650 -0.873299  0.039917  2.557055  0.938051
# 5  5,treatment -0.991817 -0.481936 -2.348089 -0.513383  2.789018 -0.999760
# 6      6,group -2.849103 -0.807993  0.273214 -0.285252  1.328339  0.793613
# 7        7,two  1.963108 -0.022526  1.978242 -0.496433 -0.222407  2.401807
# 8      8,study  1.296604  0.002335  0.880456 -2.507720 -0.141256 -1.581384
# 9        9,may -4.636498  1.044709 -2.069155  2.338934  0.499289 -1.866674
#
#          7         8         9   ...        42        43        44        45  \
# ...
